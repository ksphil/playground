# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('dataset.csv')

# %%
df.head()

# %%
indexname = df[df['TV']>0.2*10**12].index

df.drop(indexname, inplace = True)
plt.scatter(df['TV'],df['sales'])
plt.xlabel('Amount spent')
plt.ylabel('unit solds')
# Out:
# Text(0, 0.5, 'unit solds')

# %%
plt.scatter(df['radio'],df['sales'])
plt.xlabel('Amount spent')
plt.ylabel('unit solds')
# Out:
# Text(0, 0.5, 'unit solds')

# %%
plt.scatter(df['newspaper'],df['sales'])
plt.xlabel('Amount spent')
plt.ylabel('unit solds')
# Out:
# Text(0, 0.5, 'unit solds')

# %%
df.corr()
# Out:
#                  id        TV     radio  newspaper     sales
# id         1.000000  0.012054 -0.101220  -0.157635 -0.043127
# TV         0.012054  1.000000  0.005597   0.041540  0.773056
# radio     -0.101220  0.005597  1.000000   0.342301  0.550588
# newspaper -0.157635  0.041540  0.342301   1.000000  0.235145
# sales     -0.043127  0.773056  0.550588   0.235145  1.000000
